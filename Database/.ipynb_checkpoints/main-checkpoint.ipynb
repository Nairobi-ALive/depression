# %%
# This is Main function.
# Extracting streaming data from Twitter, pre-processing, and loading into MySQL

import credentials # Import api/access_token keys from credentials.py
import settings # Import related setting constants from pogdb.py 

import re
import tweepy
from textblob import TextBlob
# Out:
# Collecting textblob
#   Using cached textblob-0.15.3-py2.py3-none-any.whl (636 kB)
# Requirement already satisfied: nltk>=3.1 in /home/gtechzilla/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages (from textblob) (3.4.5)
# Requirement already satisfied: six in /home/gtechzilla/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages (from nltk>=3.1->textblob) (1.14.0)
# Installing collected packages: textblob
# Successfully installed textblob-0.15.3

# %%
# Import api/access_token keys from credentials.py
import credentials
auth  = tweepy.OAuthHandler(credentials.API_KEY, \
                            credentials.API_SECRET_KEY)
auth.set_access_token(credentials.ACCESS_TOKEN,  \
                      credentials.ACCESS_TOKEN_SECRET)
api = tweepy.API(auth)

# %%
#The fuctions are used to clean the tweets
def clean_tweet(self, tweet): 
    ''' 
    Use sumple regex statemnents to clean tweet text by removing links and special characters
    '''
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t]) \
                                |(\w+:\/\/\S+)", " ", tweet).split()) 
def deEmojify(text):
    '''
    Strip all non-ASCII characters to remove emoji characters
    '''
    if text:
        return text.encode('ascii', 'ignore').decode('ascii')
    else:
        return None

# %%
#This connnects to the database, checks if a table {"Tablename"} exits, if not creates one and closes the connection
import os
import psycopg2

dbconn = psycopg2.connect("host=ec2-52-207-25-133.compute-1.amazonaws.com dbname=d8e9au4m77k9b1 user=twvlbubsgabvpj password=53cf31e1928ac9f0ec3ec5554a92bfa96ddb693b7bb3b31df2bbf3784cc66f6a")
if dbconn:
    print("Connected")
    '''
    Check if this table exits. If not, then create a new one.
    '''
    mycursor = dbconn.cursor()
    """mycursor.execute(
    SELECT COUNT(*) FROM information_schema.tables WHERE table_schema = '{0}'.format(settings.TABLE_NAME))
    print("table exists")"""
    mycursor.execute("select * from information_schema.tables where table_name=%s", ('nairobitweets',))
    if bool(mycursor.rowcount) == False:
    
        mycursor.execute("CREATE TABLE {} ({})".format(settings.TABLE_NAME, settings.TABLE_ATTRIBUTES))
        print("Table does not exist so it has been created")
        dbconn.commit()
        mycursor.close()
    else:
        print("Table already exists.")
        dbconn.commit()
        mycursor.close()
else:
    print('Not connected')
# Out:
# Connected
# Table already exists.

# %%
#creating a listener to watch for our data
#has two functions
#on_status it to check for tweets
#on_error is to stop tweet checking incase a limit is reached
class MyStreamListener(tweepy.StreamListener):
    '''
    Tweets are known as “status updates”. So the Status class in tweepy has properties describing the tweet.
    https://developer.twitter.com/en/docs/tweets/data-dictionary/overview/tweet-object.html
    '''
    
    def on_status(self, status):
        '''
        Extract info from tweets
        '''
        
        if status.retweeted:
            # Avoid retweeted info, and only original tweets will be received
            return True
        # Extract attributes from each tweet
        id_str = status.id_str
        created_at = status.created_at
        text = deEmojify(status.text)    # Pre-processing the text  
        #sentiment = TextBlob(text).sentiment
        #polarity = sentiment.polarity
        #subjectivity = sentiment.subjectivity
        
        #user_created_at = status.user.created_at
        user_location = deEmojify(status.user.location)
        #user_description = deEmojify(status.user.description)
        #user_followers_count =status.user.followers_count
        longitude = None
        latitude = None
        if status.coordinates:
            longitude = status.coordinates['coordinates'][0]
            latitude = status.coordinates['coordinates'][1]
            print(longitude)
            print(latitude)
        retweet_count = status.retweet_count
        favorite_count = status.favorite_count
        
        print(status.text)
        print("Long: {}, Lati: {}".format(longitude, latitude))
        
        # Store all data in MySQL
        if dbconn:
            dbcursor = dbconn.cursor()
            sql = "INSERT INTO {} (id_str,created_at,text,\
                user_location,\
                longitude,\
                latitude, retweet_count, favorite_count) VALUES \
                (%s, %s, %s, %s, %s, %s, %s, %s)".format(settings.TABLE_NAME)
            val = (id_str, created_at, text,\
                  user_location,longitude, latitude, retweet_count, favorite_count)
            dbcursor.execute(sql, val)
            dbconn.commit()
    
    def on_error(self, status_code):
        '''
        Since Twitter API has rate limits, stop scraping data as it exceed to the thresold.
        '''
        if status_code == 420:
            # return False to disconnect the stream
            return False

# %%
#This calls the class myStreamListener thereby witing into the database
'''places = api.search(query="Nairobi", granularity="city")
place_id = places[0].id
public_tweets = api.search(q="place:%s" %place_id)
'''
GEOBOX_WORLD = [-180,-90,180,90]
GEOBOX_NAIROBI = [36.542329,-1.538666,37.186403,-1.052647]
while True:
    try:
        myStreamListener = MyStreamListener()
        myStream = tweepy.Stream(auth = api.auth, listener = myStreamListener)
        myStream.filter(languages=["en"], locations=GEOBOX_NAIROBI)
        dbconn.commit()
        # Close the postgres connection as it finished
        # However, this won't be reached as the stream listener won't stop automatically
        # Press STOP button to finish the process.
    except:
        dbconn = psycopg2.connect("host=ec2-52-207-25-133.compute-1.amazonaws.com dbname=d8e9au4m77k9b1 user=twvlbubsgabvpj password=53cf31e1928ac9f0ec3ec5554a92bfa96ddb693b7bb3b31df2bbf3784cc66f6a")
        myStreamListener = MyStreamListener()
        myStream = tweepy.Stream(auth = api.auth, listener = myStreamListener)
        myStream.filter(languages=["en"], locations=GEOBOX_NAIROBI)
        dbconn.commit()
# Out:
# Happiest of birthdays Twin @promqwyn Keep winning and shinning.  😍
# Long: None, Lati: None
# I was this woman 😭😭
# Scared, ashamed, fearful. After years of swearing I'd never stay in an abusive relationship...… https://t.co/rTMC52sOtd
# Long: None, Lati: None
# Then you hear some crazy people telling is to elect Ruto come 2022? We need brain donation @Ziloopi
# Long: None, Lati: None
# @lilydale37 Hows you ?
# Long: None, Lati: None
# "Imagine refusing to make 5K a week"
#
# Okay but didn't I just lend you 5$ last week? Nigga move 💀
# Long: None, Lati: None
# LOML 😍😍😍😍
# Long: None, Lati: None
# @JatohPrincessAm @jamal_magak @slyrie @imBarasa @HEBabuOwino Wow! We are living in an amazing world.
# I can turn a n… https://t.co/vtPLkfXtmO
# Long: None, Lati: None
# @carol_kimemia Honesty
# Long: None, Lati: None
# @_Hiram_254 Kabisa 🙌  have a good one
# Long: None, Lati: None
# The memories on this @Iamchrismartin tune though... 😅 #VybezMVP
# Long: None, Lati: None
# @Phann_tastic Mzalendo and they are secrets that drain our energies because we gotta hide them
# Long: None, Lati: None
# Morning Mzalendo @Phann_tastic I believe you owe me something
# Long: None, Lati: None
# @Nyagolp1 @lmkenya @RevGrey @MaryT_KE @maithyamuthama @ackchristchurch With basic needs like food or clothing? Au sio
# Long: None, Lati: None
# @omwanaballer @NervilleOdongo @d__adriko 😂😂😂drink your money 😂
# Long: None, Lati: None
# @alberto_Januzaj 😂😂 I missed that profile of yours
# Long: None, Lati: None
# @eliudkibii She's been looking for nee jobs since she became a minister
# Long: None, Lati: None
# Long: 36.81666667, Lati: -1.28333333
# Check out this episode. #podcasts #audiobooks #castbox https://t.co/fcHWSHNSUp
# Long: None, Lati: None
# @shyolympia Good night.
# Long: None, Lati: None
# @pywaya @OmbetaC What's wrong in hating Raila ?
# Long: None, Lati: None
# Mpee agware
# Long: None, Lati: None
# Head bands are basically my thing...my head can't do without them😂 https://t.co/jzCSYmlPBz
# Long: None, Lati: None
# After the short pizza menus you could order from, we had to get you some fast options.
# @cafe_havanake with yummy pi… https://t.co/Em3D6tUMZj
# Long: None, Lati: None
# @Jabali_Jr @osumo_brad my pall Monday is the day
# Long: None, Lati: None
# Kenya receives mobile labs to enhance testing capacity https://t.co/lp2462duSv
# Long: None, Lati: None
# Why did I wake up with a strong desire to do push ups and squats?
# I willingly want to do them.
# Something isn’t right.
# Long: None, Lati: None
# That slide and hooks...beautiful
# Long: None, Lati: None
# Didnt meaning that if your receiving your salary the end months everthing is ok
# that salary your injoying is from my tax payer
# Long: None, Lati: None
# xtiandela doing the most to uplift girls. much respect. 🤣✊🏿
# Long: None, Lati: None
# Atwoli and Murathe cannot  advice any president in this world. The only thing they can do with a president is crack… https://t.co/GESZfP2EM8
# Long: None, Lati: None
# Gov´t to establish 47 new legal metrology laboratories countrywide https://t.co/H2AdzJiFuI
# Long: None, Lati: None
# @Fredi_ngala @Gideon_Kitheka Depends on location
# Long: None, Lati: None
# Morning Beautiful People
# Long: None, Lati: None
# I cry even when i don't try.. Next question?!
# Long: None, Lati: None
# @quigitonga My Car Sacco
# Long: None, Lati: None
# @kilundeezy @mitch_mrefu you alway waste your time writing rhymes n singing who raised you
# Long: None, Lati: None
# @droid254 I don't remember you signing the forms for joining car twitter.
# Long: None, Lati: None
# @Fredi_ngala @Gideon_Kitheka Where you want it delivered
# Long: None, Lati: None
# Ghost... Call me casper!
# Long: None, Lati: None
# Happy birthday @MercyKe33359212
# Long: None, Lati: None
# @Safaricom_Care I have been having problems with my home fibre speeds. For the last 3 days safaricom says they will… https://t.co/ZVXlxtTkPO
# Long: None, Lati: None
# @Kilimall still waiting
# Long: None, Lati: None
# 36.81436851
# -1.27638923
# SKIZA keep your eyes on JESUS
# kama nyumba haina TOKENS wataona GIZA
# #linkinbio
# #SHORTBABABAARZ EP1… https://t.co/WoNKlRYcFp
# Long: 36.81436851, Lati: -1.27638923
# You never know what you get till you lose it all.
#
# #LuckyDube
# Long: None, Lati: None
# @SpiceFMKE @EricLatiff @nduokoh @DrMercyKorir But the Mandera story was so heartbreaking😕 apart from the few most o… https://t.co/pa5AYPBLQU
# Long: None, Lati: None
# It buys you things that make you happy..
# Long: None, Lati: None
# @kilundeezy @mitch_mrefu where your music career is
# Long: None, Lati: None
# Anyone got a Wacom tablet and pen they're willing sell? (Or even just a pen).
#
# Must be yours.
# No middlemen please.
# Long: None, Lati: None
# @SookieMurage Oh man. 😓😓😓 Me too!
# Long: None, Lati: None
# @Maureen_SonieKE @Jc_Mwaniki Happy birthday to him
# Long: None, Lati: None
# @_Mohkay Looks super delicious 😋
# Long: None, Lati: None
# @JILLKUI I know! 😔
# Long: None, Lati: None
# @JLGachanja Yes.. I cant run after 6:30am
# Long: None, Lati: None
# YARA having identified the gap to achieving high yields, has introduced foliar fertilisers under the brand… https://t.co/RaS5FmkNWT
# Long: None, Lati: None
# Guidelines this early.. !
# Long: None, Lati: None
# @TheStarBreaking WITCHCRAFT is real!
#
# The occult
# Long: None, Lati: None
# @Mkiri14 @WahomeHon @MutahiNgunyi @moseskuria_MP Dumbo IEBC count votes of up to governorship,the system does the rest.
# Long: None, Lati: None
# @Zed_shantall Thanks. I've been thinking of grilling on my balcony only that I'm afraid the smoke wil soot the ceil… https://t.co/TGG3hejBxs
# Long: None, Lati: None
# @NationBreaking WITCHCRAFT
#
# #SatanicAct
# Long: None, Lati: None
# @i_aim_tyga Makes you feel like you are getting a discount.
# Long: None, Lati: None
# 37.85
# 0.4
# Passionate About Buses | Back in the Days.
#
# MASH COOL | KAU 488D
#
# #Kenya🇰🇪
# #bwtztbt
# #MashCool
# #busworldtanzania… https://t.co/8EiRsAfVs3
# Long: 37.85, Lati: 0.4
# @muthoni_emm My sincere condolences 💜
# Long: None, Lati: None
# @ruthnyambane @KBonimtetezi Totally. Not like he was doing it pro bono, and even he did, he had vested interests wh… https://t.co/Q7PFdqShOu
# Long: None, Lati: None
# @xysist So what exactly should one look for in a comp coz those specs ain't something that should let you down.
# Long: None, Lati: None
# Alive and grateful. Good morning fam
# Long: None, Lati: None
# @honkabogo Everyone should read this for more insight https://t.co/PHhv91L6Cc
# Long: None, Lati: None
# @martingicheru Downgrade.
#
# Better clearance tho.
# Long: None, Lati: None
# @LordChitechi @KBonimtetezi Even if he did offer pro bono services, they were pegged on some vested interests which… https://t.co/QEbYlTKP3T
# Long: None, Lati: None
# @WMMartha We are completing the journey
# Long: None, Lati: None
# 36.665
# -1.246
# Ever wanted to know which one's the fastest netwprk/MiFi in Nairobi? Click the link in my bio and find out! 🔥 🔥 🔥… https://t.co/j1vT9lpOBm
# Long: 36.665, Lati: -1.246
# #YaraVita application is not a substitute of dry applied fertilisers but a complement for optimal crop yields .
#
# T… https://t.co/X1knvtKyTk
# Long: None, Lati: None
# @shyolympia Two days ago
# Long: None, Lati: None
# Babu Owino breathes
# KOT : you shot someone and you're out here breathing like that😂😂😂😂😂
# Long: None, Lati: None
# Y'all never learn 😂😂 https://t.co/R2tQ91bnAP
# Long: None, Lati: None
# @ItsMainaKageni @MwalimChurchill man that song.... Mariah Carey.... taken me up... gooose gooosebumps @Classic105Kenya #MainaAndKingangi
# Long: None, Lati: None
# @glow_elias @jackwereW @Prof_Owiti This makes it even more awkward
# Long: None, Lati: None
# Woke up today and totally felt out of place career wise! I need a change. I’m I having a midlife crisis? What is a midlife crisis?
# Long: None, Lati: None
# @JuliusMmasi Kithure Kinditi too, White bearded
# Long: None, Lati: None
# @Steven__Kamau Right?
# Long: None, Lati: None
# @PeterNj01282051 @Gideon_Kitheka @25 @22 Find my number in your DM
# Long: None, Lati: None
# 36.8167
# -1.28333
# Boys club is never a new thing.... @JalangoMwenyewe @edgarobare ....started long before we @ My Happy Place https://t.co/nWDgEvbC2P
# Long: 36.8167, Lati: -1.28333
# TBT manenos in politics @WilliamsRuto  has come far and we are ahead to fulfill his dreams, goals and vision soon s… https://t.co/q1fVx3OEZe
# Long: None, Lati: None
# @JeremyKimbo “That which offers no resistance, overcomes the hardest substances. That which offers no resistance ca… https://t.co/mQdBqia7wr
# Long: None, Lati: None
# @black_rossie I can be your stepson
# Long: None, Lati: None
# @kikes12 @BravinYuri @Patricio_Clemen I belong to both😂😂😂
# Long: None, Lati: None
# @ntvkenya Jubilee need election first from grassroots first to know how to leave.
# Long: None, Lati: None
# I totally agree with what grand mullah said.
# Long: None, Lati: None
# Demonstration is key to pass across your point.Good session today with my lad. 😃 https://t.co/pu04Jvgboc
# Long: None, Lati: None
# Morning ass pale kwa Tory Lanez 🤣🤣🤣🤣
# Long: None, Lati: None
# @davidxmacharia @TrevWall @Wangu_M I’m Dead 😂😂😂 ‘my beanie has folds for every failed startup I worked for’
# Long: None, Lati: None
# Woke up today and totally felt out of place career wise! I need a change. Am I having a midlife crisis? What is a m… https://t.co/21OWDAZt0Q
# Long: None, Lati: None
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     312         try:
# --> 313             return self.connection.recv_into(*args, **kwargs)
#     314         except OpenSSL.SSL.SysCallError as e:
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1839             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1840         self._raise_ssl_error(self._ssl, result)
#    1841
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1645         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1646             raise WantReadError()
#    1647         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-ecc96d25230b> in <module>
#      11         myStream = tweepy.Stream(auth = api.auth, listener = myStreamListener)
# ---> 12         myStream.filter(languages=["en"], locations=GEOBOX_NAIROBI)
#      13         dbconn.commit()
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/tweepy/streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/tweepy/streaming.py in _start(self, is_async)
#     388         else:
# --> 389             self._run()
#     390
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/tweepy/streaming.py in _run(self)
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/tweepy/streaming.py in read_line(self, sep)
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     506                 cache_content = False
# --> 507                 data = self._fp.read(amt) if not fp_closed else b""
#     508                 if (
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/http/client.py in read(self, amt)
#     456             b = bytearray(amt)
# --> 457             n = self.readinto(b)
#     458             return memoryview(b)[:n].tobytes()
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/http/client.py in readinto(self, b)
#     490         if self.chunked:
# --> 491             return self._readinto_chunked(b)
#     492
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/http/client.py in _readinto_chunked(self, b)
#     585             while True:
# --> 586                 chunk_left = self._get_chunk_left()
#     587                 if chunk_left is None:
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/http/client.py in _get_chunk_left(self)
#     553             try:
# --> 554                 chunk_left = self._read_next_chunk_size()
#     555             except ValueError:
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/http/client.py in _read_next_chunk_size(self)
#     513         # Read the next chunk size from the file
# --> 514         line = self.fp.readline(_MAXLINE + 1)
#     515         if len(line) > _MAXLINE:
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/socket.py in readinto(self, b)
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     324         except OpenSSL.SSL.WantReadError:
# --> 325             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     326                 raise timeout("The read operation timed out")
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/urllib3/util/wait.py in wait_for_read(sock, timeout)
#     145     """
# --> 146     return wait_for_socket(sock, read=True, timeout=timeout)
#     147
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/urllib3/util/wait.py in poll_wait_for_socket(sock, read, write, timeout)
#     106
# --> 107     return bool(_retry_on_intr(do_poll, timeout))
#     108
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/urllib3/util/wait.py in _retry_on_intr(fn, timeout)
#      42     def _retry_on_intr(fn, timeout):
# ---> 43         return fn(timeout)
#      44
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/urllib3/util/wait.py in do_poll(t)
#     104             t *= 1000
# --> 105         return poll_obj.poll(t)
#     106
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# WantReadError                             Traceback (most recent call last)
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     312         try:
# --> 313             return self.connection.recv_into(*args, **kwargs)
#     314         except OpenSSL.SSL.SysCallError as e:
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1839             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1840         self._raise_ssl_error(self._ssl, result)
#    1841
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1645         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1646             raise WantReadError()
#    1647         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-ecc96d25230b> in <module>
#      19         myStreamListener = MyStreamListener()
#      20         myStream = tweepy.Stream(auth = api.auth, listener = myStreamListener)
# ---> 21         myStream.filter(languages=["en"], locations=GEOBOX_NAIROBI)
#      22         dbconn.commit()
#      23
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/tweepy/streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/tweepy/streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/tweepy/streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/tweepy/streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     505             else:
#     506                 cache_content = False
# --> 507                 data = self._fp.read(amt) if not fp_closed else b""
#     508                 if (
#     509                     amt != 0 and not data
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/http/client.py in read(self, amt)
#     455             # Amount is given, implement using readinto
#     456             b = bytearray(amt)
# --> 457             n = self.readinto(b)
#     458             return memoryview(b)[:n].tobytes()
#     459         else:
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/http/client.py in readinto(self, b)
#     489
#     490         if self.chunked:
# --> 491             return self._readinto_chunked(b)
#     492
#     493         if self.length is not None:
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/http/client.py in _readinto_chunked(self, b)
#     584         try:
#     585             while True:
# --> 586                 chunk_left = self._get_chunk_left()
#     587                 if chunk_left is None:
#     588                     return total_bytes
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/http/client.py in _get_chunk_left(self)
#     552                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     553             try:
# --> 554                 chunk_left = self._read_next_chunk_size()
#     555             except ValueError:
#     556                 raise IncompleteRead(b'')
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/http/client.py in _read_next_chunk_size(self)
#     512     def _read_next_chunk_size(self):
#     513         # Read the next chunk size from the file
# --> 514         line = self.fp.readline(_MAXLINE + 1)
#     515         if len(line) > _MAXLINE:
#     516             raise LineTooLong("chunk size")
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     323                 raise
#     324         except OpenSSL.SSL.WantReadError:
# --> 325             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     326                 raise timeout("The read operation timed out")
#     327             else:
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/urllib3/util/wait.py in wait_for_read(sock, timeout)
#     144     Returns True if the socket is readable, or False if the timeout expired.
#     145     """
# --> 146     return wait_for_socket(sock, read=True, timeout=timeout)
#     147
#     148
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/urllib3/util/wait.py in poll_wait_for_socket(sock, read, write, timeout)
#     105         return poll_obj.poll(t)
#     106
# --> 107     return bool(_retry_on_intr(do_poll, timeout))
#     108
#     109
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/urllib3/util/wait.py in _retry_on_intr(fn, timeout)
#      41     # Modern Python, that retries syscalls by default
#      42     def _retry_on_intr(fn, timeout):
# ---> 43         return fn(timeout)
#      44
#      45
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/urllib3/util/wait.py in do_poll(t)
#     103         if t is not None:
#     104             t *= 1000
# --> 105         return poll_obj.poll(t)
#     106
#     107     return bool(_retry_on_intr(do_poll, timeout))
#
# KeyboardInterrupt:

# %%
#Fetch data from database

# %%
import psycopg2 as pg
import pandas.io.sql as psql
import time
import pandas as pd
def getdata():
    connection = pg.connect("host=ec2-52-207-25-133.compute-1.amazonaws.com dbname=d8e9au4m77k9b1 user=twvlbubsgabvpj password=53cf31e1928ac9f0ec3ec5554a92bfa96ddb693b7bb3b31df2bbf3784cc66f6a")
    dataframe = psql.read_sql('SELECT * FROM nairobitweets', connection)
    dataframe.count
    print(dataframe)
    time.sleep(60)

while True:
    getdata()
# Out:
#                   id_str          created_at  \
# 0    1261992353511940098 2020-05-17 12:09:58
# 1    1261992370243080192 2020-05-17 12:10:02
# 2    1261992400861396992 2020-05-17 12:10:09
# 3    1261992502732734465 2020-05-17 12:10:33
# 4    1261992563785039872 2020-05-17 12:10:48
# ..                   ...                 ...
# 496  1262021126621986816 2020-05-17 14:04:18
# 497  1262021135417384962 2020-05-17 14:04:20
# 498  1262021193667883008 2020-05-17 14:04:34
# 499  1262021252786552835 2020-05-17 14:04:48
# 500  1262021543120580608 2020-05-17 14:05:57
#
#                                                   text  polarity  \
# 0            @McMwiti Chief... https://t.co/P4gM7BhxOG         0
# 1             @TausiMiss @osumo_brad @fkschindler Yeah         0
# 2               Sunday seshhhh, on a Madonna playlist!         0
# 3      What is the solution if COVID-19 stays with us?         0
# 4                           @iam_brayann check your DM         0
# ..                                                 ...       ...
# 496                    What analysis is @JerotichSeii          0
# 497                                essential services?         0
# 498                       @Kilda_ Lol. You hate uzito?         0
# 499                               @iKeynan_ Amazon lol         1
# 500  @NjeriThorne The silver mountain particularly ...         0
#
#      subjectivity      user_created_at    user_location  \
# 0               0  2009-04-10 18:13:16   Nairobi, Kenya
# 1               0  2014-11-19 08:22:50  My Happy Place.
# 2               0  2010-11-09 13:12:06   Nairobi, Kenya
# 3               0  2014-06-15 14:14:23               &
# 4               0  2009-05-01 21:14:20            Kenya
# ..            ...                  ...              ...
# 496             0  2012-02-28 06:04:47            Kenya
# 497             0  2012-02-15 15:42:35     limuru,Kenya
# 498             1  2010-09-21 14:17:06   Nairobi, Kenya
# 499             1  2010-09-21 14:17:06   Nairobi, Kenya
# 500             0  2018-12-25 03:27:25            Kenya
#
#                                       user_description  user_followers_count  \
# 0    Itinerant gourmand | Bookish | Managing Editor...                  7077
# 1    Daughter of the Most High!Simple and unique!lo...                 12968
# 2    simple,hardworking,very ambitious gal and not ...                   564
# 3                          PR & communication/ Finance                  3452
# 4    I AM THE PARTY\n#JoeMfalmeLive ~\nConnecting p...                202575
# ..                                                 ...                   ...
# 496                                          Economist                 40110
# 497  A dad,a farmer,animal activist-tusks belong to...                   200
# 498  I play video games. Please don't RT my jokes w...                  3453
# 499  I play video games. Please don't RT my jokes w...                  3453
# 500  R.C Christian|Social Scientist|Public Servant|...                   120
#
#      longitude  latitude  retweet_count  favorite_count
# 0          NaN       NaN              0               0
# 1          NaN       NaN              0               0
# 2          NaN       NaN              0               0
# 3          NaN       NaN              0               0
# 4          NaN       NaN              0               0
# ..         ...       ...            ...             ...
# 496        NaN       NaN              0               0
# 497        NaN       NaN              0               0
# 498        NaN       NaN              0               0
# 499        NaN       NaN              0               0
# 500        NaN       NaN              0               0
#
# [501 rows x 13 columns]
#                   id_str          created_at  \
# 0    1261992353511940098 2020-05-17 12:09:58
# 1    1261992370243080192 2020-05-17 12:10:02
# 2    1261992400861396992 2020-05-17 12:10:09
# 3    1261992502732734465 2020-05-17 12:10:33
# 4    1261992563785039872 2020-05-17 12:10:48
# ..                   ...                 ...
# 496  1262021126621986816 2020-05-17 14:04:18
# 497  1262021135417384962 2020-05-17 14:04:20
# 498  1262021193667883008 2020-05-17 14:04:34
# 499  1262021252786552835 2020-05-17 14:04:48
# 500  1262021543120580608 2020-05-17 14:05:57
#
#                                                   text  polarity  \
# 0            @McMwiti Chief... https://t.co/P4gM7BhxOG         0
# 1             @TausiMiss @osumo_brad @fkschindler Yeah         0
# 2               Sunday seshhhh, on a Madonna playlist!         0
# 3      What is the solution if COVID-19 stays with us?         0
# 4                           @iam_brayann check your DM         0
# ..                                                 ...       ...
# 496                    What analysis is @JerotichSeii          0
# 497                                essential services?         0
# 498                       @Kilda_ Lol. You hate uzito?         0
# 499                               @iKeynan_ Amazon lol         1
# 500  @NjeriThorne The silver mountain particularly ...         0
#
#      subjectivity      user_created_at    user_location  \
# 0               0  2009-04-10 18:13:16   Nairobi, Kenya
# 1               0  2014-11-19 08:22:50  My Happy Place.
# 2               0  2010-11-09 13:12:06   Nairobi, Kenya
# 3               0  2014-06-15 14:14:23               &
# 4               0  2009-05-01 21:14:20            Kenya
# ..            ...                  ...              ...
# 496             0  2012-02-28 06:04:47            Kenya
# 497             0  2012-02-15 15:42:35     limuru,Kenya
# 498             1  2010-09-21 14:17:06   Nairobi, Kenya
# 499             1  2010-09-21 14:17:06   Nairobi, Kenya
# 500             0  2018-12-25 03:27:25            Kenya
#
#                                       user_description  user_followers_count  \
# 0    Itinerant gourmand | Bookish | Managing Editor...                  7077
# 1    Daughter of the Most High!Simple and unique!lo...                 12968
# 2    simple,hardworking,very ambitious gal and not ...                   564
# 3                          PR & communication/ Finance                  3452
# 4    I AM THE PARTY\n#JoeMfalmeLive ~\nConnecting p...                202575
# ..                                                 ...                   ...
# 496                                          Economist                 40110
# 497  A dad,a farmer,animal activist-tusks belong to...                   200
# 498  I play video games. Please don't RT my jokes w...                  3453
# 499  I play video games. Please don't RT my jokes w...                  3453
# 500  R.C Christian|Social Scientist|Public Servant|...                   120
#
#      longitude  latitude  retweet_count  favorite_count
# 0          NaN       NaN              0               0
# 1          NaN       NaN              0               0
# 2          NaN       NaN              0               0
# 3          NaN       NaN              0               0
# 4          NaN       NaN              0               0
# ..         ...       ...            ...             ...
# 496        NaN       NaN              0               0
# 497        NaN       NaN              0               0
# 498        NaN       NaN              0               0
# 499        NaN       NaN              0               0
# 500        NaN       NaN              0               0
#
# [501 rows x 13 columns]
#                   id_str          created_at  \
# 0    1261992353511940098 2020-05-17 12:09:58
# 1    1261992370243080192 2020-05-17 12:10:02
# 2    1261992400861396992 2020-05-17 12:10:09
# 3    1261992502732734465 2020-05-17 12:10:33
# 4    1261992563785039872 2020-05-17 12:10:48
# ..                   ...                 ...
# 496  1262021126621986816 2020-05-17 14:04:18
# 497  1262021135417384962 2020-05-17 14:04:20
# 498  1262021193667883008 2020-05-17 14:04:34
# 499  1262021252786552835 2020-05-17 14:04:48
# 500  1262021543120580608 2020-05-17 14:05:57
#
#                                                   text  polarity  \
# 0            @McMwiti Chief... https://t.co/P4gM7BhxOG         0
# 1             @TausiMiss @osumo_brad @fkschindler Yeah         0
# 2               Sunday seshhhh, on a Madonna playlist!         0
# 3      What is the solution if COVID-19 stays with us?         0
# 4                           @iam_brayann check your DM         0
# ..                                                 ...       ...
# 496                    What analysis is @JerotichSeii          0
# 497                                essential services?         0
# 498                       @Kilda_ Lol. You hate uzito?         0
# 499                               @iKeynan_ Amazon lol         1
# 500  @NjeriThorne The silver mountain particularly ...         0
#
#      subjectivity      user_created_at    user_location  \
# 0               0  2009-04-10 18:13:16   Nairobi, Kenya
# 1               0  2014-11-19 08:22:50  My Happy Place.
# 2               0  2010-11-09 13:12:06   Nairobi, Kenya
# 3               0  2014-06-15 14:14:23               &
# 4               0  2009-05-01 21:14:20            Kenya
# ..            ...                  ...              ...
# 496             0  2012-02-28 06:04:47            Kenya
# 497             0  2012-02-15 15:42:35     limuru,Kenya
# 498             1  2010-09-21 14:17:06   Nairobi, Kenya
# 499             1  2010-09-21 14:17:06   Nairobi, Kenya
# 500             0  2018-12-25 03:27:25            Kenya
#
#                                       user_description  user_followers_count  \
# 0    Itinerant gourmand | Bookish | Managing Editor...                  7077
# 1    Daughter of the Most High!Simple and unique!lo...                 12968
# 2    simple,hardworking,very ambitious gal and not ...                   564
# 3                          PR & communication/ Finance                  3452
# 4    I AM THE PARTY\n#JoeMfalmeLive ~\nConnecting p...                202575
# ..                                                 ...                   ...
# 496                                          Economist                 40110
# 497  A dad,a farmer,animal activist-tusks belong to...                   200
# 498  I play video games. Please don't RT my jokes w...                  3453
# 499  I play video games. Please don't RT my jokes w...                  3453
# 500  R.C Christian|Social Scientist|Public Servant|...                   120
#
#      longitude  latitude  retweet_count  favorite_count
# 0          NaN       NaN              0               0
# 1          NaN       NaN              0               0
# 2          NaN       NaN              0               0
# 3          NaN       NaN              0               0
# 4          NaN       NaN              0               0
# ..         ...       ...            ...             ...
# 496        NaN       NaN              0               0
# 497        NaN       NaN              0               0
# 498        NaN       NaN              0               0
# 499        NaN       NaN              0               0
# 500        NaN       NaN              0               0
#
# [501 rows x 13 columns]
#                   id_str          created_at  \
# 0    1261992353511940098 2020-05-17 12:09:58
# 1    1261992370243080192 2020-05-17 12:10:02
# 2    1261992400861396992 2020-05-17 12:10:09
# 3    1261992502732734465 2020-05-17 12:10:33
# 4    1261992563785039872 2020-05-17 12:10:48
# ..                   ...                 ...
# 496  1262021126621986816 2020-05-17 14:04:18
# 497  1262021135417384962 2020-05-17 14:04:20
# 498  1262021193667883008 2020-05-17 14:04:34
# 499  1262021252786552835 2020-05-17 14:04:48
# 500  1262021543120580608 2020-05-17 14:05:57
#
#                                                   text  polarity  \
# 0            @McMwiti Chief... https://t.co/P4gM7BhxOG         0
# 1             @TausiMiss @osumo_brad @fkschindler Yeah         0
# 2               Sunday seshhhh, on a Madonna playlist!         0
# 3      What is the solution if COVID-19 stays with us?         0
# 4                           @iam_brayann check your DM         0
# ..                                                 ...       ...
# 496                    What analysis is @JerotichSeii          0
# 497                                essential services?         0
# 498                       @Kilda_ Lol. You hate uzito?         0
# 499                               @iKeynan_ Amazon lol         1
# 500  @NjeriThorne The silver mountain particularly ...         0
#
#      subjectivity      user_created_at    user_location  \
# 0               0  2009-04-10 18:13:16   Nairobi, Kenya
# 1               0  2014-11-19 08:22:50  My Happy Place.
# 2               0  2010-11-09 13:12:06   Nairobi, Kenya
# 3               0  2014-06-15 14:14:23               &
# 4               0  2009-05-01 21:14:20            Kenya
# ..            ...                  ...              ...
# 496             0  2012-02-28 06:04:47            Kenya
# 497             0  2012-02-15 15:42:35     limuru,Kenya
# 498             1  2010-09-21 14:17:06   Nairobi, Kenya
# 499             1  2010-09-21 14:17:06   Nairobi, Kenya
# 500             0  2018-12-25 03:27:25            Kenya
#
#                                       user_description  user_followers_count  \
# 0    Itinerant gourmand | Bookish | Managing Editor...                  7077
# 1    Daughter of the Most High!Simple and unique!lo...                 12968
# 2    simple,hardworking,very ambitious gal and not ...                   564
# 3                          PR & communication/ Finance                  3452
# 4    I AM THE PARTY\n#JoeMfalmeLive ~\nConnecting p...                202575
# ..                                                 ...                   ...
# 496                                          Economist                 40110
# 497  A dad,a farmer,animal activist-tusks belong to...                   200
# 498  I play video games. Please don't RT my jokes w...                  3453
# 499  I play video games. Please don't RT my jokes w...                  3453
# 500  R.C Christian|Social Scientist|Public Servant|...                   120
#
#      longitude  latitude  retweet_count  favorite_count
# 0          NaN       NaN              0               0
# 1          NaN       NaN              0               0
# 2          NaN       NaN              0               0
# 3          NaN       NaN              0               0
# 4          NaN       NaN              0               0
# ..         ...       ...            ...             ...
# 496        NaN       NaN              0               0
# 497        NaN       NaN              0               0
# 498        NaN       NaN              0               0
# 499        NaN       NaN              0               0
# 500        NaN       NaN              0               0
#
# [501 rows x 13 columns]
#                   id_str          created_at  \
# 0    1261992353511940098 2020-05-17 12:09:58
# 1    1261992370243080192 2020-05-17 12:10:02
# 2    1261992400861396992 2020-05-17 12:10:09
# 3    1261992502732734465 2020-05-17 12:10:33
# 4    1261992563785039872 2020-05-17 12:10:48
# ..                   ...                 ...
# 496  1262021126621986816 2020-05-17 14:04:18
# 497  1262021135417384962 2020-05-17 14:04:20
# 498  1262021193667883008 2020-05-17 14:04:34
# 499  1262021252786552835 2020-05-17 14:04:48
# 500  1262021543120580608 2020-05-17 14:05:57
#
#                                                   text  polarity  \
# 0            @McMwiti Chief... https://t.co/P4gM7BhxOG         0
# 1             @TausiMiss @osumo_brad @fkschindler Yeah         0
# 2               Sunday seshhhh, on a Madonna playlist!         0
# 3      What is the solution if COVID-19 stays with us?         0
# 4                           @iam_brayann check your DM         0
# ..                                                 ...       ...
# 496                    What analysis is @JerotichSeii          0
# 497                                essential services?         0
# 498                       @Kilda_ Lol. You hate uzito?         0
# 499                               @iKeynan_ Amazon lol         1
# 500  @NjeriThorne The silver mountain particularly ...         0
#
#      subjectivity      user_created_at    user_location  \
# 0               0  2009-04-10 18:13:16   Nairobi, Kenya
# 1               0  2014-11-19 08:22:50  My Happy Place.
# 2               0  2010-11-09 13:12:06   Nairobi, Kenya
# 3               0  2014-06-15 14:14:23               &
# 4               0  2009-05-01 21:14:20            Kenya
# ..            ...                  ...              ...
# 496             0  2012-02-28 06:04:47            Kenya
# 497             0  2012-02-15 15:42:35     limuru,Kenya
# 498             1  2010-09-21 14:17:06   Nairobi, Kenya
# 499             1  2010-09-21 14:17:06   Nairobi, Kenya
# 500             0  2018-12-25 03:27:25            Kenya
#
#                                       user_description  user_followers_count  \
# 0    Itinerant gourmand | Bookish | Managing Editor...                  7077
# 1    Daughter of the Most High!Simple and unique!lo...                 12968
# 2    simple,hardworking,very ambitious gal and not ...                   564
# 3                          PR & communication/ Finance                  3452
# 4    I AM THE PARTY\n#JoeMfalmeLive ~\nConnecting p...                202575
# ..                                                 ...                   ...
# 496                                          Economist                 40110
# 497  A dad,a farmer,animal activist-tusks belong to...                   200
# 498  I play video games. Please don't RT my jokes w...                  3453
# 499  I play video games. Please don't RT my jokes w...                  3453
# 500  R.C Christian|Social Scientist|Public Servant|...                   120
#
#      longitude  latitude  retweet_count  favorite_count
# 0          NaN       NaN              0               0
# 1          NaN       NaN              0               0
# 2          NaN       NaN              0               0
# 3          NaN       NaN              0               0
# 4          NaN       NaN              0               0
# ..         ...       ...            ...             ...
# 496        NaN       NaN              0               0
# 497        NaN       NaN              0               0
# 498        NaN       NaN              0               0
# 499        NaN       NaN              0               0
# 500        NaN       NaN              0               0
#
# [501 rows x 13 columns]
#                   id_str          created_at  \
# 0    1261992353511940098 2020-05-17 12:09:58
# 1    1261992370243080192 2020-05-17 12:10:02
# 2    1261992400861396992 2020-05-17 12:10:09
# 3    1261992502732734465 2020-05-17 12:10:33
# 4    1261992563785039872 2020-05-17 12:10:48
# ..                   ...                 ...
# 496  1262021126621986816 2020-05-17 14:04:18
# 497  1262021135417384962 2020-05-17 14:04:20
# 498  1262021193667883008 2020-05-17 14:04:34
# 499  1262021252786552835 2020-05-17 14:04:48
# 500  1262021543120580608 2020-05-17 14:05:57
#
#                                                   text  polarity  \
# 0            @McMwiti Chief... https://t.co/P4gM7BhxOG         0
# 1             @TausiMiss @osumo_brad @fkschindler Yeah         0
# 2               Sunday seshhhh, on a Madonna playlist!         0
# 3      What is the solution if COVID-19 stays with us?         0
# 4                           @iam_brayann check your DM         0
# ..                                                 ...       ...
# 496                    What analysis is @JerotichSeii          0
# 497                                essential services?         0
# 498                       @Kilda_ Lol. You hate uzito?         0
# 499                               @iKeynan_ Amazon lol         1
# 500  @NjeriThorne The silver mountain particularly ...         0
#
#      subjectivity      user_created_at    user_location  \
# 0               0  2009-04-10 18:13:16   Nairobi, Kenya
# 1               0  2014-11-19 08:22:50  My Happy Place.
# 2               0  2010-11-09 13:12:06   Nairobi, Kenya
# 3               0  2014-06-15 14:14:23               &
# 4               0  2009-05-01 21:14:20            Kenya
# ..            ...                  ...              ...
# 496             0  2012-02-28 06:04:47            Kenya
# 497             0  2012-02-15 15:42:35     limuru,Kenya
# 498             1  2010-09-21 14:17:06   Nairobi, Kenya
# 499             1  2010-09-21 14:17:06   Nairobi, Kenya
# 500             0  2018-12-25 03:27:25            Kenya
#
#                                       user_description  user_followers_count  \
# 0    Itinerant gourmand | Bookish | Managing Editor...                  7077
# 1    Daughter of the Most High!Simple and unique!lo...                 12968
# 2    simple,hardworking,very ambitious gal and not ...                   564
# 3                          PR & communication/ Finance                  3452
# 4    I AM THE PARTY\n#JoeMfalmeLive ~\nConnecting p...                202575
# ..                                                 ...                   ...
# 496                                          Economist                 40110
# 497  A dad,a farmer,animal activist-tusks belong to...                   200
# 498  I play video games. Please don't RT my jokes w...                  3453
# 499  I play video games. Please don't RT my jokes w...                  3453
# 500  R.C Christian|Social Scientist|Public Servant|...                   120
#
#      longitude  latitude  retweet_count  favorite_count
# 0          NaN       NaN              0               0
# 1          NaN       NaN              0               0
# 2          NaN       NaN              0               0
# 3          NaN       NaN              0               0
# 4          NaN       NaN              0               0
# ..         ...       ...            ...             ...
# 496        NaN       NaN              0               0
# 497        NaN       NaN              0               0
# 498        NaN       NaN              0               0
# 499        NaN       NaN              0               0
# 500        NaN       NaN              0               0
#
# [501 rows x 13 columns]
#                   id_str          created_at  \
# 0    1261992353511940098 2020-05-17 12:09:58
# 1    1261992370243080192 2020-05-17 12:10:02
# 2    1261992400861396992 2020-05-17 12:10:09
# 3    1261992502732734465 2020-05-17 12:10:33
# 4    1261992563785039872 2020-05-17 12:10:48
# ..                   ...                 ...
# 496  1262021126621986816 2020-05-17 14:04:18
# 497  1262021135417384962 2020-05-17 14:04:20
# 498  1262021193667883008 2020-05-17 14:04:34
# 499  1262021252786552835 2020-05-17 14:04:48
# 500  1262021543120580608 2020-05-17 14:05:57
#
#                                                   text  polarity  \
# 0            @McMwiti Chief... https://t.co/P4gM7BhxOG         0
# 1             @TausiMiss @osumo_brad @fkschindler Yeah         0
# 2               Sunday seshhhh, on a Madonna playlist!         0
# 3      What is the solution if COVID-19 stays with us?         0
# 4                           @iam_brayann check your DM         0
# ..                                                 ...       ...
# 496                    What analysis is @JerotichSeii          0
# 497                                essential services?         0
# 498                       @Kilda_ Lol. You hate uzito?         0
# 499                               @iKeynan_ Amazon lol         1
# 500  @NjeriThorne The silver mountain particularly ...         0
#
#      subjectivity      user_created_at    user_location  \
# 0               0  2009-04-10 18:13:16   Nairobi, Kenya
# 1               0  2014-11-19 08:22:50  My Happy Place.
# 2               0  2010-11-09 13:12:06   Nairobi, Kenya
# 3               0  2014-06-15 14:14:23               &
# 4               0  2009-05-01 21:14:20            Kenya
# ..            ...                  ...              ...
# 496             0  2012-02-28 06:04:47            Kenya
# 497             0  2012-02-15 15:42:35     limuru,Kenya
# 498             1  2010-09-21 14:17:06   Nairobi, Kenya
# 499             1  2010-09-21 14:17:06   Nairobi, Kenya
# 500             0  2018-12-25 03:27:25            Kenya
#
#                                       user_description  user_followers_count  \
# 0    Itinerant gourmand | Bookish | Managing Editor...                  7077
# 1    Daughter of the Most High!Simple and unique!lo...                 12968
# 2    simple,hardworking,very ambitious gal and not ...                   564
# 3                          PR & communication/ Finance                  3452
# 4    I AM THE PARTY\n#JoeMfalmeLive ~\nConnecting p...                202575
# ..                                                 ...                   ...
# 496                                          Economist                 40110
# 497  A dad,a farmer,animal activist-tusks belong to...                   200
# 498  I play video games. Please don't RT my jokes w...                  3453
# 499  I play video games. Please don't RT my jokes w...                  3453
# 500  R.C Christian|Social Scientist|Public Servant|...                   120
#
#      longitude  latitude  retweet_count  favorite_count
# 0          NaN       NaN              0               0
# 1          NaN       NaN              0               0
# 2          NaN       NaN              0               0
# 3          NaN       NaN              0               0
# 4          NaN       NaN              0               0
# ..         ...       ...            ...             ...
# 496        NaN       NaN              0               0
# 497        NaN       NaN              0               0
# 498        NaN       NaN              0               0
# 499        NaN       NaN              0               0
# 500        NaN       NaN              0               0
#
# [501 rows x 13 columns]
#                   id_str          created_at  \
# 0    1261992353511940098 2020-05-17 12:09:58
# 1    1261992370243080192 2020-05-17 12:10:02
# 2    1261992400861396992 2020-05-17 12:10:09
# 3    1261992502732734465 2020-05-17 12:10:33
# 4    1261992563785039872 2020-05-17 12:10:48
# ..                   ...                 ...
# 496  1262021126621986816 2020-05-17 14:04:18
# 497  1262021135417384962 2020-05-17 14:04:20
# 498  1262021193667883008 2020-05-17 14:04:34
# 499  1262021252786552835 2020-05-17 14:04:48
# 500  1262021543120580608 2020-05-17 14:05:57
#
#                                                   text  polarity  \
# 0            @McMwiti Chief... https://t.co/P4gM7BhxOG         0
# 1             @TausiMiss @osumo_brad @fkschindler Yeah         0
# 2               Sunday seshhhh, on a Madonna playlist!         0
# 3      What is the solution if COVID-19 stays with us?         0
# 4                           @iam_brayann check your DM         0
# ..                                                 ...       ...
# 496                    What analysis is @JerotichSeii          0
# 497                                essential services?         0
# 498                       @Kilda_ Lol. You hate uzito?         0
# 499                               @iKeynan_ Amazon lol         1
# 500  @NjeriThorne The silver mountain particularly ...         0
#
#      subjectivity      user_created_at    user_location  \
# 0               0  2009-04-10 18:13:16   Nairobi, Kenya
# 1               0  2014-11-19 08:22:50  My Happy Place.
# 2               0  2010-11-09 13:12:06   Nairobi, Kenya
# 3               0  2014-06-15 14:14:23               &
# 4               0  2009-05-01 21:14:20            Kenya
# ..            ...                  ...              ...
# 496             0  2012-02-28 06:04:47            Kenya
# 497             0  2012-02-15 15:42:35     limuru,Kenya
# 498             1  2010-09-21 14:17:06   Nairobi, Kenya
# 499             1  2010-09-21 14:17:06   Nairobi, Kenya
# 500             0  2018-12-25 03:27:25            Kenya
#
#                                       user_description  user_followers_count  \
# 0    Itinerant gourmand | Bookish | Managing Editor...                  7077
# 1    Daughter of the Most High!Simple and unique!lo...                 12968
# 2    simple,hardworking,very ambitious gal and not ...                   564
# 3                          PR & communication/ Finance                  3452
# 4    I AM THE PARTY\n#JoeMfalmeLive ~\nConnecting p...                202575
# ..                                                 ...                   ...
# 496                                          Economist                 40110
# 497  A dad,a farmer,animal activist-tusks belong to...                   200
# 498  I play video games. Please don't RT my jokes w...                  3453
# 499  I play video games. Please don't RT my jokes w...                  3453
# 500  R.C Christian|Social Scientist|Public Servant|...                   120
#
#      longitude  latitude  retweet_count  favorite_count
# 0          NaN       NaN              0               0
# 1          NaN       NaN              0               0
# 2          NaN       NaN              0               0
# 3          NaN       NaN              0               0
# 4          NaN       NaN              0               0
# ..         ...       ...            ...             ...
# 496        NaN       NaN              0               0
# 497        NaN       NaN              0               0
# 498        NaN       NaN              0               0
# 499        NaN       NaN              0               0
# 500        NaN       NaN              0               0
#
# [501 rows x 13 columns]
#                   id_str          created_at  \
# 0    1261992353511940098 2020-05-17 12:09:58
# 1    1261992370243080192 2020-05-17 12:10:02
# 2    1261992400861396992 2020-05-17 12:10:09
# 3    1261992502732734465 2020-05-17 12:10:33
# 4    1261992563785039872 2020-05-17 12:10:48
# ..                   ...                 ...
# 496  1262021126621986816 2020-05-17 14:04:18
# 497  1262021135417384962 2020-05-17 14:04:20
# 498  1262021193667883008 2020-05-17 14:04:34
# 499  1262021252786552835 2020-05-17 14:04:48
# 500  1262021543120580608 2020-05-17 14:05:57
#
#                                                   text  polarity  \
# 0            @McMwiti Chief... https://t.co/P4gM7BhxOG         0
# 1             @TausiMiss @osumo_brad @fkschindler Yeah         0
# 2               Sunday seshhhh, on a Madonna playlist!         0
# 3      What is the solution if COVID-19 stays with us?         0
# 4                           @iam_brayann check your DM         0
# ..                                                 ...       ...
# 496                    What analysis is @JerotichSeii          0
# 497                                essential services?         0
# 498                       @Kilda_ Lol. You hate uzito?         0
# 499                               @iKeynan_ Amazon lol         1
# 500  @NjeriThorne The silver mountain particularly ...         0
#
#      subjectivity      user_created_at    user_location  \
# 0               0  2009-04-10 18:13:16   Nairobi, Kenya
# 1               0  2014-11-19 08:22:50  My Happy Place.
# 2               0  2010-11-09 13:12:06   Nairobi, Kenya
# 3               0  2014-06-15 14:14:23               &
# 4               0  2009-05-01 21:14:20            Kenya
# ..            ...                  ...              ...
# 496             0  2012-02-28 06:04:47            Kenya
# 497             0  2012-02-15 15:42:35     limuru,Kenya
# 498             1  2010-09-21 14:17:06   Nairobi, Kenya
# 499             1  2010-09-21 14:17:06   Nairobi, Kenya
# 500             0  2018-12-25 03:27:25            Kenya
#
#                                       user_description  user_followers_count  \
# 0    Itinerant gourmand | Bookish | Managing Editor...                  7077
# 1    Daughter of the Most High!Simple and unique!lo...                 12968
# 2    simple,hardworking,very ambitious gal and not ...                   564
# 3                          PR & communication/ Finance                  3452
# 4    I AM THE PARTY\n#JoeMfalmeLive ~\nConnecting p...                202575
# ..                                                 ...                   ...
# 496                                          Economist                 40110
# 497  A dad,a farmer,animal activist-tusks belong to...                   200
# 498  I play video games. Please don't RT my jokes w...                  3453
# 499  I play video games. Please don't RT my jokes w...                  3453
# 500  R.C Christian|Social Scientist|Public Servant|...                   120
#
#      longitude  latitude  retweet_count  favorite_count
# 0          NaN       NaN              0               0
# 1          NaN       NaN              0               0
# 2          NaN       NaN              0               0
# 3          NaN       NaN              0               0
# 4          NaN       NaN              0               0
# ..         ...       ...            ...             ...
# 496        NaN       NaN              0               0
# 497        NaN       NaN              0               0
# 498        NaN       NaN              0               0
# 499        NaN       NaN              0               0
# 500        NaN       NaN              0               0
#
# [501 rows x 13 columns]
#                   id_str          created_at  \
# 0    1261992353511940098 2020-05-17 12:09:58
# 1    1261992370243080192 2020-05-17 12:10:02
# 2    1261992400861396992 2020-05-17 12:10:09
# 3    1261992502732734465 2020-05-17 12:10:33
# 4    1261992563785039872 2020-05-17 12:10:48
# ..                   ...                 ...
# 496  1262021126621986816 2020-05-17 14:04:18
# 497  1262021135417384962 2020-05-17 14:04:20
# 498  1262021193667883008 2020-05-17 14:04:34
# 499  1262021252786552835 2020-05-17 14:04:48
# 500  1262021543120580608 2020-05-17 14:05:57
#
#                                                   text  polarity  \
# 0            @McMwiti Chief... https://t.co/P4gM7BhxOG         0
# 1             @TausiMiss @osumo_brad @fkschindler Yeah         0
# 2               Sunday seshhhh, on a Madonna playlist!         0
# 3      What is the solution if COVID-19 stays with us?         0
# 4                           @iam_brayann check your DM         0
# ..                                                 ...       ...
# 496                    What analysis is @JerotichSeii          0
# 497                                essential services?         0
# 498                       @Kilda_ Lol. You hate uzito?         0
# 499                               @iKeynan_ Amazon lol         1
# 500  @NjeriThorne The silver mountain particularly ...         0
#
#      subjectivity      user_created_at    user_location  \
# 0               0  2009-04-10 18:13:16   Nairobi, Kenya
# 1               0  2014-11-19 08:22:50  My Happy Place.
# 2               0  2010-11-09 13:12:06   Nairobi, Kenya
# 3               0  2014-06-15 14:14:23               &
# 4               0  2009-05-01 21:14:20            Kenya
# ..            ...                  ...              ...
# 496             0  2012-02-28 06:04:47            Kenya
# 497             0  2012-02-15 15:42:35     limuru,Kenya
# 498             1  2010-09-21 14:17:06   Nairobi, Kenya
# 499             1  2010-09-21 14:17:06   Nairobi, Kenya
# 500             0  2018-12-25 03:27:25            Kenya
#
#                                       user_description  user_followers_count  \
# 0    Itinerant gourmand | Bookish | Managing Editor...                  7077
# 1    Daughter of the Most High!Simple and unique!lo...                 12968
# 2    simple,hardworking,very ambitious gal and not ...                   564
# 3                          PR & communication/ Finance                  3452
# 4    I AM THE PARTY\n#JoeMfalmeLive ~\nConnecting p...                202575
# ..                                                 ...                   ...
# 496                                          Economist                 40110
# 497  A dad,a farmer,animal activist-tusks belong to...                   200
# 498  I play video games. Please don't RT my jokes w...                  3453
# 499  I play video games. Please don't RT my jokes w...                  3453
# 500  R.C Christian|Social Scientist|Public Servant|...                   120
#
#      longitude  latitude  retweet_count  favorite_count
# 0          NaN       NaN              0               0
# 1          NaN       NaN              0               0
# 2          NaN       NaN              0               0
# 3          NaN       NaN              0               0
# 4          NaN       NaN              0               0
# ..         ...       ...            ...             ...
# 496        NaN       NaN              0               0
# 497        NaN       NaN              0               0
# 498        NaN       NaN              0               0
# 499        NaN       NaN              0               0
# 500        NaN       NaN              0               0
#
# [501 rows x 13 columns]
#                   id_str          created_at  \
# 0    1261992353511940098 2020-05-17 12:09:58
# 1    1261992370243080192 2020-05-17 12:10:02
# 2    1261992400861396992 2020-05-17 12:10:09
# 3    1261992502732734465 2020-05-17 12:10:33
# 4    1261992563785039872 2020-05-17 12:10:48
# ..                   ...                 ...
# 496  1262021126621986816 2020-05-17 14:04:18
# 497  1262021135417384962 2020-05-17 14:04:20
# 498  1262021193667883008 2020-05-17 14:04:34
# 499  1262021252786552835 2020-05-17 14:04:48
# 500  1262021543120580608 2020-05-17 14:05:57
#
#                                                   text  polarity  \
# 0            @McMwiti Chief... https://t.co/P4gM7BhxOG         0
# 1             @TausiMiss @osumo_brad @fkschindler Yeah         0
# 2               Sunday seshhhh, on a Madonna playlist!         0
# 3      What is the solution if COVID-19 stays with us?         0
# 4                           @iam_brayann check your DM         0
# ..                                                 ...       ...
# 496                    What analysis is @JerotichSeii          0
# 497                                essential services?         0
# 498                       @Kilda_ Lol. You hate uzito?         0
# 499                               @iKeynan_ Amazon lol         1
# 500  @NjeriThorne The silver mountain particularly ...         0
#
#      subjectivity      user_created_at    user_location  \
# 0               0  2009-04-10 18:13:16   Nairobi, Kenya
# 1               0  2014-11-19 08:22:50  My Happy Place.
# 2               0  2010-11-09 13:12:06   Nairobi, Kenya
# 3               0  2014-06-15 14:14:23               &
# 4               0  2009-05-01 21:14:20            Kenya
# ..            ...                  ...              ...
# 496             0  2012-02-28 06:04:47            Kenya
# 497             0  2012-02-15 15:42:35     limuru,Kenya
# 498             1  2010-09-21 14:17:06   Nairobi, Kenya
# 499             1  2010-09-21 14:17:06   Nairobi, Kenya
# 500             0  2018-12-25 03:27:25            Kenya
#
#                                       user_description  user_followers_count  \
# 0    Itinerant gourmand | Bookish | Managing Editor...                  7077
# 1    Daughter of the Most High!Simple and unique!lo...                 12968
# 2    simple,hardworking,very ambitious gal and not ...                   564
# 3                          PR & communication/ Finance                  3452
# 4    I AM THE PARTY\n#JoeMfalmeLive ~\nConnecting p...                202575
# ..                                                 ...                   ...
# 496                                          Economist                 40110
# 497  A dad,a farmer,animal activist-tusks belong to...                   200
# 498  I play video games. Please don't RT my jokes w...                  3453
# 499  I play video games. Please don't RT my jokes w...                  3453
# 500  R.C Christian|Social Scientist|Public Servant|...                   120
#
#      longitude  latitude  retweet_count  favorite_count
# 0          NaN       NaN              0               0
# 1          NaN       NaN              0               0
# 2          NaN       NaN              0               0
# 3          NaN       NaN              0               0
# 4          NaN       NaN              0               0
# ..         ...       ...            ...             ...
# 496        NaN       NaN              0               0
# 497        NaN       NaN              0               0
# 498        NaN       NaN              0               0
# 499        NaN       NaN              0               0
# 500        NaN       NaN              0               0
#
# [501 rows x 13 columns]
#                   id_str          created_at  \
# 0    1261992353511940098 2020-05-17 12:09:58
# 1    1261992370243080192 2020-05-17 12:10:02
# 2    1261992400861396992 2020-05-17 12:10:09
# 3    1261992502732734465 2020-05-17 12:10:33
# 4    1261992563785039872 2020-05-17 12:10:48
# ..                   ...                 ...
# 496  1262021126621986816 2020-05-17 14:04:18
# 497  1262021135417384962 2020-05-17 14:04:20
# 498  1262021193667883008 2020-05-17 14:04:34
# 499  1262021252786552835 2020-05-17 14:04:48
# 500  1262021543120580608 2020-05-17 14:05:57
#
#                                                   text  polarity  \
# 0            @McMwiti Chief... https://t.co/P4gM7BhxOG         0
# 1             @TausiMiss @osumo_brad @fkschindler Yeah         0
# 2               Sunday seshhhh, on a Madonna playlist!         0
# 3      What is the solution if COVID-19 stays with us?         0
# 4                           @iam_brayann check your DM         0
# ..                                                 ...       ...
# 496                    What analysis is @JerotichSeii          0
# 497                                essential services?         0
# 498                       @Kilda_ Lol. You hate uzito?         0
# 499                               @iKeynan_ Amazon lol         1
# 500  @NjeriThorne The silver mountain particularly ...         0
#
#      subjectivity      user_created_at    user_location  \
# 0               0  2009-04-10 18:13:16   Nairobi, Kenya
# 1               0  2014-11-19 08:22:50  My Happy Place.
# 2               0  2010-11-09 13:12:06   Nairobi, Kenya
# 3               0  2014-06-15 14:14:23               &
# 4               0  2009-05-01 21:14:20            Kenya
# ..            ...                  ...              ...
# 496             0  2012-02-28 06:04:47            Kenya
# 497             0  2012-02-15 15:42:35     limuru,Kenya
# 498             1  2010-09-21 14:17:06   Nairobi, Kenya
# 499             1  2010-09-21 14:17:06   Nairobi, Kenya
# 500             0  2018-12-25 03:27:25            Kenya
#
#                                       user_description  user_followers_count  \
# 0    Itinerant gourmand | Bookish | Managing Editor...                  7077
# 1    Daughter of the Most High!Simple and unique!lo...                 12968
# 2    simple,hardworking,very ambitious gal and not ...                   564
# 3                          PR & communication/ Finance                  3452
# 4    I AM THE PARTY\n#JoeMfalmeLive ~\nConnecting p...                202575
# ..                                                 ...                   ...
# 496                                          Economist                 40110
# 497  A dad,a farmer,animal activist-tusks belong to...                   200
# 498  I play video games. Please don't RT my jokes w...                  3453
# 499  I play video games. Please don't RT my jokes w...                  3453
# 500  R.C Christian|Social Scientist|Public Servant|...                   120
#
#      longitude  latitude  retweet_count  favorite_count
# 0          NaN       NaN              0               0
# 1          NaN       NaN              0               0
# 2          NaN       NaN              0               0
# 3          NaN       NaN              0               0
# 4          NaN       NaN              0               0
# ..         ...       ...            ...             ...
# 496        NaN       NaN              0               0
# 497        NaN       NaN              0               0
# 498        NaN       NaN              0               0
# 499        NaN       NaN              0               0
# 500        NaN       NaN              0               0
#
# [501 rows x 13 columns]
#                   id_str          created_at  \
# 0    1261992353511940098 2020-05-17 12:09:58
# 1    1261992370243080192 2020-05-17 12:10:02
# 2    1261992400861396992 2020-05-17 12:10:09
# 3    1261992502732734465 2020-05-17 12:10:33
# 4    1261992563785039872 2020-05-17 12:10:48
# ..                   ...                 ...
# 496  1262021126621986816 2020-05-17 14:04:18
# 497  1262021135417384962 2020-05-17 14:04:20
# 498  1262021193667883008 2020-05-17 14:04:34
# 499  1262021252786552835 2020-05-17 14:04:48
# 500  1262021543120580608 2020-05-17 14:05:57
#
#                                                   text  polarity  \
# 0            @McMwiti Chief... https://t.co/P4gM7BhxOG         0
# 1             @TausiMiss @osumo_brad @fkschindler Yeah         0
# 2               Sunday seshhhh, on a Madonna playlist!         0
# 3      What is the solution if COVID-19 stays with us?         0
# 4                           @iam_brayann check your DM         0
# ..                                                 ...       ...
# 496                    What analysis is @JerotichSeii          0
# 497                                essential services?         0
# 498                       @Kilda_ Lol. You hate uzito?         0
# 499                               @iKeynan_ Amazon lol         1
# 500  @NjeriThorne The silver mountain particularly ...         0
#
#      subjectivity      user_created_at    user_location  \
# 0               0  2009-04-10 18:13:16   Nairobi, Kenya
# 1               0  2014-11-19 08:22:50  My Happy Place.
# 2               0  2010-11-09 13:12:06   Nairobi, Kenya
# 3               0  2014-06-15 14:14:23               &
# 4               0  2009-05-01 21:14:20            Kenya
# ..            ...                  ...              ...
# 496             0  2012-02-28 06:04:47            Kenya
# 497             0  2012-02-15 15:42:35     limuru,Kenya
# 498             1  2010-09-21 14:17:06   Nairobi, Kenya
# 499             1  2010-09-21 14:17:06   Nairobi, Kenya
# 500             0  2018-12-25 03:27:25            Kenya
#
#                                       user_description  user_followers_count  \
# 0    Itinerant gourmand | Bookish | Managing Editor...                  7077
# 1    Daughter of the Most High!Simple and unique!lo...                 12968
# 2    simple,hardworking,very ambitious gal and not ...                   564
# 3                          PR & communication/ Finance                  3452
# ...
# 497  1262021135417384962 2020-05-17 14:04:20
# 498  1262021193667883008 2020-05-17 14:04:34
# 499  1262021252786552835 2020-05-17 14:04:48
# 500  1262021543120580608 2020-05-17 14:05:57
#
#                                                   text  polarity  \
# 0            @McMwiti Chief... https://t.co/P4gM7BhxOG         0
# 1             @TausiMiss @osumo_brad @fkschindler Yeah         0
# 2               Sunday seshhhh, on a Madonna playlist!         0
# 3      What is the solution if COVID-19 stays with us?         0
# 4                           @iam_brayann check your DM         0
# ..                                                 ...       ...
# 496                    What analysis is @JerotichSeii          0
# 497                                essential services?         0
# 498                       @Kilda_ Lol. You hate uzito?         0
# 499                               @iKeynan_ Amazon lol         1
# 500  @NjeriThorne The silver mountain particularly ...         0
#
#      subjectivity      user_created_at    user_location  \
# 0               0  2009-04-10 18:13:16   Nairobi, Kenya
# 1               0  2014-11-19 08:22:50  My Happy Place.
# 2               0  2010-11-09 13:12:06   Nairobi, Kenya
# 3               0  2014-06-15 14:14:23               &
# 4               0  2009-05-01 21:14:20            Kenya
# ..            ...                  ...              ...
# 496             0  2012-02-28 06:04:47            Kenya
# 497             0  2012-02-15 15:42:35     limuru,Kenya
# 498             1  2010-09-21 14:17:06   Nairobi, Kenya
# 499             1  2010-09-21 14:17:06   Nairobi, Kenya
# 500             0  2018-12-25 03:27:25            Kenya
#
#                                       user_description  user_followers_count  \
# 0    Itinerant gourmand | Bookish | Managing Editor...                  7077
# 1    Daughter of the Most High!Simple and unique!lo...                 12968
# 2    simple,hardworking,very ambitious gal and not ...                   564
# 3                          PR & communication/ Finance                  3452
# 4    I AM THE PARTY\n#JoeMfalmeLive ~\nConnecting p...                202575
# ..                                                 ...                   ...
# 496                                          Economist                 40110
# 497  A dad,a farmer,animal activist-tusks belong to...                   200
# 498  I play video games. Please don't RT my jokes w...                  3453
# 499  I play video games. Please don't RT my jokes w...                  3453
# 500  R.C Christian|Social Scientist|Public Servant|...                   120
#
#      longitude  latitude  retweet_count  favorite_count
# 0          NaN       NaN              0               0
# 1          NaN       NaN              0               0
# 2          NaN       NaN              0               0
# 3          NaN       NaN              0               0
# 4          NaN       NaN              0               0
# ..         ...       ...            ...             ...
# 496        NaN       NaN              0               0
# 497        NaN       NaN              0               0
# 498        NaN       NaN              0               0
# 499        NaN       NaN              0               0
# 500        NaN       NaN              0               0
#
# [501 rows x 13 columns]
#                   id_str          created_at  \
# 0    1261992353511940098 2020-05-17 12:09:58
# 1    1261992370243080192 2020-05-17 12:10:02
# 2    1261992400861396992 2020-05-17 12:10:09
# 3    1261992502732734465 2020-05-17 12:10:33
# 4    1261992563785039872 2020-05-17 12:10:48
# ..                   ...                 ...
# 496  1262021126621986816 2020-05-17 14:04:18
# 497  1262021135417384962 2020-05-17 14:04:20
# 498  1262021193667883008 2020-05-17 14:04:34
# 499  1262021252786552835 2020-05-17 14:04:48
# 500  1262021543120580608 2020-05-17 14:05:57
#
#                                                   text  polarity  \
# 0            @McMwiti Chief... https://t.co/P4gM7BhxOG         0
# 1             @TausiMiss @osumo_brad @fkschindler Yeah         0
# 2               Sunday seshhhh, on a Madonna playlist!         0
# 3      What is the solution if COVID-19 stays with us?         0
# 4                           @iam_brayann check your DM         0
# ..                                                 ...       ...
# 496                    What analysis is @JerotichSeii          0
# 497                                essential services?         0
# 498                       @Kilda_ Lol. You hate uzito?         0
# 499                               @iKeynan_ Amazon lol         1
# 500  @NjeriThorne The silver mountain particularly ...         0
#
#      subjectivity      user_created_at    user_location  \
# 0               0  2009-04-10 18:13:16   Nairobi, Kenya
# 1               0  2014-11-19 08:22:50  My Happy Place.
# 2               0  2010-11-09 13:12:06   Nairobi, Kenya
# 3               0  2014-06-15 14:14:23               &
# 4               0  2009-05-01 21:14:20            Kenya
# ..            ...                  ...              ...
# 496             0  2012-02-28 06:04:47            Kenya
# 497             0  2012-02-15 15:42:35     limuru,Kenya
# 498             1  2010-09-21 14:17:06   Nairobi, Kenya
# 499             1  2010-09-21 14:17:06   Nairobi, Kenya
# 500             0  2018-12-25 03:27:25            Kenya
#
#                                       user_description  user_followers_count  \
# 0    Itinerant gourmand | Bookish | Managing Editor...                  7077
# 1    Daughter of the Most High!Simple and unique!lo...                 12968
# 2    simple,hardworking,very ambitious gal and not ...                   564
# 3                          PR & communication/ Finance                  3452
# 4    I AM THE PARTY\n#JoeMfalmeLive ~\nConnecting p...                202575
# ..                                                 ...                   ...
# 496                                          Economist                 40110
# 497  A dad,a farmer,animal activist-tusks belong to...                   200
# 498  I play video games. Please don't RT my jokes w...                  3453
# 499  I play video games. Please don't RT my jokes w...                  3453
# 500  R.C Christian|Social Scientist|Public Servant|...                   120
#
#      longitude  latitude  retweet_count  favorite_count
# 0          NaN       NaN              0               0
# 1          NaN       NaN              0               0
# 2          NaN       NaN              0               0
# 3          NaN       NaN              0               0
# 4          NaN       NaN              0               0
# ..         ...       ...            ...             ...
# 496        NaN       NaN              0               0
# 497        NaN       NaN              0               0
# 498        NaN       NaN              0               0
# 499        NaN       NaN              0               0
# 500        NaN       NaN              0               0
#
# [501 rows x 13 columns]
#                   id_str          created_at  \
# 0    1261992353511940098 2020-05-17 12:09:58
# 1    1261992370243080192 2020-05-17 12:10:02
# 2    1261992400861396992 2020-05-17 12:10:09
# 3    1261992502732734465 2020-05-17 12:10:33
# 4    1261992563785039872 2020-05-17 12:10:48
# ..                   ...                 ...
# 496  1262021126621986816 2020-05-17 14:04:18
# 497  1262021135417384962 2020-05-17 14:04:20
# 498  1262021193667883008 2020-05-17 14:04:34
# 499  1262021252786552835 2020-05-17 14:04:48
# 500  1262021543120580608 2020-05-17 14:05:57
#
#                                                   text  polarity  \
# 0            @McMwiti Chief... https://t.co/P4gM7BhxOG         0
# 1             @TausiMiss @osumo_brad @fkschindler Yeah         0
# 2               Sunday seshhhh, on a Madonna playlist!         0
# 3      What is the solution if COVID-19 stays with us?         0
# 4                           @iam_brayann check your DM         0
# ..                                                 ...       ...
# 496                    What analysis is @JerotichSeii          0
# 497                                essential services?         0
# 498                       @Kilda_ Lol. You hate uzito?         0
# 499                               @iKeynan_ Amazon lol         1
# 500  @NjeriThorne The silver mountain particularly ...         0
#
#      subjectivity      user_created_at    user_location  \
# 0               0  2009-04-10 18:13:16   Nairobi, Kenya
# 1               0  2014-11-19 08:22:50  My Happy Place.
# 2               0  2010-11-09 13:12:06   Nairobi, Kenya
# 3               0  2014-06-15 14:14:23               &
# 4               0  2009-05-01 21:14:20            Kenya
# ..            ...                  ...              ...
# 496             0  2012-02-28 06:04:47            Kenya
# 497             0  2012-02-15 15:42:35     limuru,Kenya
# 498             1  2010-09-21 14:17:06   Nairobi, Kenya
# 499             1  2010-09-21 14:17:06   Nairobi, Kenya
# 500             0  2018-12-25 03:27:25            Kenya
#
#                                       user_description  user_followers_count  \
# 0    Itinerant gourmand | Bookish | Managing Editor...                  7077
# 1    Daughter of the Most High!Simple and unique!lo...                 12968
# 2    simple,hardworking,very ambitious gal and not ...                   564
# 3                          PR & communication/ Finance                  3452
# 4    I AM THE PARTY\n#JoeMfalmeLive ~\nConnecting p...                202575
# ..                                                 ...                   ...
# 496                                          Economist                 40110
# 497  A dad,a farmer,animal activist-tusks belong to...                   200
# 498  I play video games. Please don't RT my jokes w...                  3453
# 499  I play video games. Please don't RT my jokes w...                  3453
# 500  R.C Christian|Social Scientist|Public Servant|...                   120
#
#      longitude  latitude  retweet_count  favorite_count
# 0          NaN       NaN              0               0
# 1          NaN       NaN              0               0
# 2          NaN       NaN              0               0
# 3          NaN       NaN              0               0
# 4          NaN       NaN              0               0
# ..         ...       ...            ...             ...
# 496        NaN       NaN              0               0
# 497        NaN       NaN              0               0
# 498        NaN       NaN              0               0
# 499        NaN       NaN              0               0
# 500        NaN       NaN              0               0
#
# [501 rows x 13 columns]
#                   id_str          created_at  \
# 0    1261992353511940098 2020-05-17 12:09:58
# 1    1261992370243080192 2020-05-17 12:10:02
# 2    1261992400861396992 2020-05-17 12:10:09
# 3    1261992502732734465 2020-05-17 12:10:33
# 4    1261992563785039872 2020-05-17 12:10:48
# ..                   ...                 ...
# 496  1262021126621986816 2020-05-17 14:04:18
# 497  1262021135417384962 2020-05-17 14:04:20
# 498  1262021193667883008 2020-05-17 14:04:34
# 499  1262021252786552835 2020-05-17 14:04:48
# 500  1262021543120580608 2020-05-17 14:05:57
#
#                                                   text  polarity  \
# 0            @McMwiti Chief... https://t.co/P4gM7BhxOG         0
# 1             @TausiMiss @osumo_brad @fkschindler Yeah         0
# 2               Sunday seshhhh, on a Madonna playlist!         0
# 3      What is the solution if COVID-19 stays with us?         0
# 4                           @iam_brayann check your DM         0
# ..                                                 ...       ...
# 496                    What analysis is @JerotichSeii          0
# 497                                essential services?         0
# 498                       @Kilda_ Lol. You hate uzito?         0
# 499                               @iKeynan_ Amazon lol         1
# 500  @NjeriThorne The silver mountain particularly ...         0
#
#      subjectivity      user_created_at    user_location  \
# 0               0  2009-04-10 18:13:16   Nairobi, Kenya
# 1               0  2014-11-19 08:22:50  My Happy Place.
# 2               0  2010-11-09 13:12:06   Nairobi, Kenya
# 3               0  2014-06-15 14:14:23               &
# 4               0  2009-05-01 21:14:20            Kenya
# ..            ...                  ...              ...
# 496             0  2012-02-28 06:04:47            Kenya
# 497             0  2012-02-15 15:42:35     limuru,Kenya
# 498             1  2010-09-21 14:17:06   Nairobi, Kenya
# 499             1  2010-09-21 14:17:06   Nairobi, Kenya
# 500             0  2018-12-25 03:27:25            Kenya
#
#                                       user_description  user_followers_count  \
# 0    Itinerant gourmand | Bookish | Managing Editor...                  7077
# 1    Daughter of the Most High!Simple and unique!lo...                 12968
# 2    simple,hardworking,very ambitious gal and not ...                   564
# 3                          PR & communication/ Finance                  3452
# 4    I AM THE PARTY\n#JoeMfalmeLive ~\nConnecting p...                202575
# ..                                                 ...                   ...
# 496                                          Economist                 40110
# 497  A dad,a farmer,animal activist-tusks belong to...                   200
# 498  I play video games. Please don't RT my jokes w...                  3453
# 499  I play video games. Please don't RT my jokes w...                  3453
# 500  R.C Christian|Social Scientist|Public Servant|...                   120
#
#      longitude  latitude  retweet_count  favorite_count
# 0          NaN       NaN              0               0
# 1          NaN       NaN              0               0
# 2          NaN       NaN              0               0
# 3          NaN       NaN              0               0
# 4          NaN       NaN              0               0
# ..         ...       ...            ...             ...
# 496        NaN       NaN              0               0
# 497        NaN       NaN              0               0
# 498        NaN       NaN              0               0
# 499        NaN       NaN              0               0
# 500        NaN       NaN              0               0
#
# [501 rows x 13 columns]
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-4-7bd28636be06> in <module>
#      11
#      12 while True:
# ---> 13     executeSomething()
#      14 while False:
#      15         dataframe = dataframe[0:0]
#
# <ipython-input-4-7bd28636be06> in executeSomething()
#       4 import pandas as pd
#       5 def executeSomething():
# ----> 6     connection = pg.connect("host=ec2-52-207-25-133.compute-1.amazonaws.com dbname=d8e9au4m77k9b1 user=twvlbubsgabvpj password=53cf31e1928ac9f0ec3ec5554a92bfa96ddb693b7bb3b31df2bbf3784cc66f6a")
#       7     dataframe = psql.read_sql('SELECT * FROM nairobitweets', connection)
#       8     dataframe.count
#
# ~/bash/lib/python3.6/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#     129         conn.cursor_factory = cursor_factory
#
# OperationalError: could not translate host name "ec2-52-207-25-133.compute-1.amazonaws.com" to address: Name or service not known
