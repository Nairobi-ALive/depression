# %%
# This is Main function.
# Extracting streaming data from Twitter, pre-processing, and loading into MySQL

import credentials # Import api/access_token keys from credentials.py
import settings # Import related setting constants from pogdb.py 

import re
import tweepy
from textblob import TextBlob

# %%
# Import api/access_token keys from credentials.py
import credentials
auth  = tweepy.OAuthHandler(credentials.API_KEY, \
                            credentials.API_SECRET_KEY)
auth.set_access_token(credentials.ACCESS_TOKEN,  \
                      credentials.ACCESS_TOKEN_SECRET)
api = tweepy.API(auth)

# %%
#The fuctions are used to clean the tweets
def clean_tweet(self, tweet): 
    ''' 
    Use sumple regex statemnents to clean tweet text by removing links and special characters
    '''
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t]) \
                                |(\w+:\/\/\S+)", " ", tweet).split()) 
def deEmojify(text):
    '''
    Strip all non-ASCII characters to remove emoji characters
    '''
    if text:
        return text.encode('ascii', 'ignore').decode('ascii')
    else:
        return None

# %%
#This connnects to the database, checks if a table {"Tablename"} exits, if not creates one and closes the connection
import os
import psycopg2

dbconn = psycopg2.connect("host=ec2-52-207-25-133.compute-1.amazonaws.com dbname=d8e9au4m77k9b1 user=twvlbubsgabvpj password=53cf31e1928ac9f0ec3ec5554a92bfa96ddb693b7bb3b31df2bbf3784cc66f6a")
if dbconn:
    print("Connected")
    '''
    Check if this table exits. If not, then create a new one.
    '''
    mycursor = dbconn.cursor()
    """mycursor.execute(
    SELECT COUNT(*) FROM information_schema.tables WHERE table_schema = '{0}'.format(settings.TABLE_NAME))
    print("table exists")"""
    mycursor.execute("select * from information_schema.tables where table_name=%s", ('nairobitweets',))
    if bool(mycursor.rowcount) == False:
    
        mycursor.execute("CREATE TABLE {} ({})".format(settings.TABLE_NAME, settings.TABLE_ATTRIBUTES))
        print("Table does not exist so it has been created")
        dbconn.commit()
        mycursor.close()
    else:
        print("Table already exists.")
        dbconn.commit()
        mycursor.close()
else:
    print('Not connected')
# Out:
# Connected
# Table already exists.

# %%
#creating a listener to watch for our data
#has two functions
#on_status it to check for tweets
#on_error is to stop tweet checking incase a limit is reached
class MyStreamListener(tweepy.StreamListener):
    '''
    Tweets are known as “status updates”. So the Status class in tweepy has properties describing the tweet.
    https://developer.twitter.com/en/docs/tweets/data-dictionary/overview/tweet-object.html
    '''
    
    def on_status(self, status):
        '''
        Extract info from tweets
        '''
        
        if status.retweeted:
            # Avoid retweeted info, and only original tweets will be received
            return True
        # Extract attributes from each tweet
        id_str = status.id_str
        created_at = status.created_at
        text = deEmojify(status.text)    # Pre-processing the text  
        #sentiment = TextBlob(text).sentiment
        #polarity = sentiment.polarity
        #subjectivity = sentiment.subjectivity
        
        #user_created_at = status.user.created_at
        user_location = deEmojify(status.user.location)
        #user_description = deEmojify(status.user.description)
        #user_followers_count =status.user.followers_count
        longitude = None
        latitude = None
        if status.coordinates:
            longitude = status.coordinates['coordinates'][0]
            latitude = status.coordinates['coordinates'][1]
            print(longitude)
            print(latitude)
        retweet_count = status.retweet_count
        favorite_count = status.favorite_count
        
        print(status.text)
        print("Long: {}, Lati: {}".format(longitude, latitude))
        
        # Store all data in MySQL
        if dbconn:
            dbcursor = dbconn.cursor()
            sql = "INSERT INTO {} (id_str,created_at,text,\
                user_location,\
                longitude,\
                latitude, retweet_count, favorite_count) VALUES \
                (%s, %s, %s, %s, %s, %s, %s, %s)".format(settings.TABLE_NAME)
            val = (id_str, created_at, text,\
                  user_location,longitude, latitude, retweet_count, favorite_count)
            dbcursor.execute(sql, val)
            dbconn.commit()
    
    def on_error(self, status_code):
        '''
        Since Twitter API has rate limits, stop scraping data as it exceed to the thresold.
        '''
        if status_code == 420:
            # return False to disconnect the stream
            return False

# %%
#This calls the class myStreamListener thereby witing into the database
'''places = api.search(query="Nairobi", granularity="city")
place_id = places[0].id
public_tweets = api.search(q="place:%s" %place_id)
'''
GEOBOX_WORLD = [-180,-90,180,90]
GEOBOX_NAIROBI = [36.542329,-1.538666,37.186403,-1.052647]
while True:
    try:
        myStreamListener = MyStreamListener()
        myStream = tweepy.Stream(auth = api.auth, listener = myStreamListener)
        myStream.filter(languages=["en"], locations=GEOBOX_NAIROBI)
        dbconn.commit()
        # Close the postgres connection as it finished
        # However, this won't be reached as the stream listener won't stop automatically
        # Press STOP button to finish the process.
    except:
        dbconn = psycopg2.connect("host=ec2-52-207-25-133.compute-1.amazonaws.com dbname=d8e9au4m77k9b1 user=twvlbubsgabvpj password=53cf31e1928ac9f0ec3ec5554a92bfa96ddb693b7bb3b31df2bbf3784cc66f6a")
        myStreamListener = MyStreamListener()
        myStream = tweepy.Stream(auth = api.auth, listener = myStreamListener)
        myStream.filter(languages=["en"], locations=GEOBOX_NAIROBI)
        dbconn.commit()
# Out:
# @EzekielMutua Amen
# Long: None, Lati: None
# @hopefmlive @WilliamMcDowell @gichuru_george I give my self away to you, I surrender everything to you Jesus… https://t.co/vTiYLbIdd3
# Long: None, Lati: None
# @hopefmlive @gichuru_george All I want is you Lord, thank you for enabling us to see this beautiful day  praying fo… https://t.co/WRcl7cDCbM
# Long: None, Lati: None
# @C_K_Lomaria Am not around. Maliza, I will launch it 😂
# Long: None, Lati: None
# Amen and amen
# #barakazamilele
# Long: None, Lati: None
# Bomboclaaaaaaaaaaat! Imma slit your throat with my fingers 😤
# Long: None, Lati: None
# 36.7059
# -1.3281
# Lovely and spacious 2 bedroom apartment to let Karen
#
# Located on kerarapon ,master ensuite,15 units in the compoun… https://t.co/2u9Y4opk8x
# Long: 36.7059, Lati: -1.3281
# @ahmedsalims Interesting I think people don't have influence
# Long: None, Lati: None
# Do not say, “Why were the former days better than these?” For you do not inquire wisely concerning this.
# Ecclesiast… https://t.co/3kNr8LS4dA
# Long: None, Lati: None
# Early to bed early to rise. Good morning World! Hello Kenya
# Long: None, Lati: None
# Good morning Liz
# #barakazamilele
# Long: None, Lati: None
# I say whoever cum first is loser in the game called sex
# Long: None, Lati: None
# Good morning the prof himuselifu
# Long: None, Lati: None
# Mwalimu.
# This z where u belong hhhhhh
# Long: None, Lati: None
# @ochogofred038 @hopefmlive @gichuru_george @kerrykagiri @mukolwe_shades @MWAKAZI_FRED @FavourEdambo11 @MillieAchero… https://t.co/4ZF8Ucfl9J
# Long: None, Lati: None
# Love
# Long: None, Lati: None
# Good morning Cecil
# #barakazamilele
# Long: None, Lati: None
# @thighnesss 😂😂 I wanted to abuse you but let's focus on Corona
# Long: None, Lati: None
# Arrogance
# Long: None, Lati: None
# @sarahkimani @PedroHipolito You've forgotten they'd even re carpet the dilapidated roads leading to the Supermarket… https://t.co/yQTZQ6t863
# Long: None, Lati: None
# Good job Daggy
# Long: None, Lati: None
# @iGachango I’m pregnant 😭
# Long: None, Lati: None
# I stopped taking you serious
# Long: None, Lati: None
# @Namuks Umeanza? My goodness. Prepare for your mind to be blown away while doing gymnastics.
# Long: None, Lati: None
# Ready for Season 3. I have so many questions. Legit didn’t move for a couple minutes after the end. Shooketh. https://t.co/vlLf4h9i3V
# Long: None, Lati: None
# Indeed he's yahwe
# #barakazamilele
# Long: None, Lati: None
# These are some of the items on the sales list this week. https://t.co/YC9yFlk6XB
# Long: None, Lati: None
# Happy birthday to your daughter may God grant her favor as she grow up #Pambazuka
# Long: None, Lati: None
# And look man, Ye's pool is nice, mine's just bigger's what I'm saying
# Long: None, Lati: None
# Amen to that sister #Pambazuka
# Long: None, Lati: None
# Thus says the LORD... https://t.co/Uy2RRBrOyM
# Long: None, Lati: None
# And every tweet he puts out suggests he deserved it
# Long: None, Lati: None
# It’s Monday morning, so let me sleep for sometime
# Long: None, Lati: None
# @GhettoRadio895
# #BREKKO
# @MajimajiKenya
# @King_Kafu @Elishifa
# Greetings team early birds??
# The early bird catches the… https://t.co/YxVVYVVYcq
# Long: None, Lati: None
# @GhettoRadio895 @MajimajiKenya @King_Kafu
# Good morning team early birds
# Straight outta benedicta utawala tuned
# #HappyNewWeek
# Long: None, Lati: None
# Confirmed 👊 👊 👊
# #BREKKO
# Long: None, Lati: None
# I wish you good fortune
# Long: None, Lati: None
# Good morning 🌞
# Long: None, Lati: None
# @modexy @Edwin_Karuga Raila, Uhuru, Ruto, Kalonzo, Mudavadi and Gidion are all the same. They are just power hungry… https://t.co/An2Z3306Ir
# Long: None, Lati: None
# Early Bird Catches The Worm.
# UTAWALA BENEDICTA LOKT. @MajimajiKenya @King_Kafu #Brekko  @GhettoRadio895
# Long: None, Lati: None
# Getting you loud and clear from benedicta utawala @GhettoRadio895 @MajimajiKenya @King_Kafu @Elishifa
# #BREKKO
# Long: None, Lati: None
# @GeorgeOnsase Morning
# Long: None, Lati: None
# @OwichBrio Morning 🌞
# Long: None, Lati: None
# @The_Dawng @Tom_michira You too
# Long: None, Lati: None
# @omuonyotieno @DicksonAvulala @Edwin_Karuga @uonbi @KEBS_ke How many Kenyans ever had their father as VP. How many… https://t.co/YssQdCxXZG
# Long: None, Lati: None
# @patrickestarian @quicksilver99 @cnnbrk You cannot use a post from a republican candidate to argue your case y’all… https://t.co/CbRF04qg7A
# Long: None, Lati: None
# @seanclinton5 Hope you good bro 😊
# Long: None, Lati: None
# @MandyNand Hope you good 😊
# Long: None, Lati: None
# @JoanShiKigwa @ItsMainaKageni @Classic105Kenya Good morning
# Long: None, Lati: None
# Then people are saying that uhunye will open up on 6th. Make it make sense!  this is a steady upward momentum.
# Long: None, Lati: None
# @seanclinton5 Great day pal
# Long: None, Lati: None
# I love waking up early aisee
# Long: None, Lati: None
# @MandyNand Me too 😊 great day pal
# Long: None, Lati: None
# @malelemohaa @keinanAbdihakim Morning captain Jazak Allah for the remainder 🙏
# Long: None, Lati: None
# @patrickestarian @quicksilver99 @cnnbrk Then again this will not work on me I’m not in your country. I’m telling yo… https://t.co/ESTNZJq6C3
# Long: None, Lati: None
# Religion that God our Father accepts as pure and faultless is this: to look after orphans and widows in their distr… https://t.co/TO8rW9e8Tu
# Long: None, Lati: None
# Before sex, you help each other get naked. After sex, you only dress yourself. Moral of the story: in life, no one… https://t.co/YvyiSlq2mU
# Long: None, Lati: None
# @ongogeblogian1 @Breaking911 Why do you ask that?
# Long: None, Lati: None
# @MullahYasin @MohaJichoPevu First of all who told you I am from nyanza? Be ignorant but don't be a blabbering fool… https://t.co/QmppF2P2K5
# Long: None, Lati: None
# @Shirohshi How much?
# Long: None, Lati: None
# The Kiambaa issues is still a big challenge to date. So many people lost their lives. #RutoWantedToKillUhuru https://t.co/DybqCi6Atw
# Long: None, Lati: None
# @Abdirizaqhassa6 Morning Ugas
# Long: None, Lati: None
# @ongogeblogian1 That reaction is way too first
# Long: None, Lati: None
# What happened to Musando? What did he do to deserve all that? #RutoWantedToKillUhuru https://t.co/5ZkQf6qnpQ
# Long: None, Lati: None
# Raila Out
# Ruto Out
# Uhuru Out
# Team Fresh Blood
# Long: None, Lati: None
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     312         try:
# --> 313             return self.connection.recv_into(*args, **kwargs)
#     314         except OpenSSL.SSL.SysCallError as e:
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1839             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1840         self._raise_ssl_error(self._ssl, result)
#    1841
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1645         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1646             raise WantReadError()
#    1647         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-ecc96d25230b> in <module>
#      11         myStream = tweepy.Stream(auth = api.auth, listener = myStreamListener)
# ---> 12         myStream.filter(languages=["en"], locations=GEOBOX_NAIROBI)
#      13         dbconn.commit()
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/tweepy/streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/tweepy/streaming.py in _start(self, is_async)
#     388         else:
# --> 389             self._run()
#     390
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/tweepy/streaming.py in _run(self)
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/tweepy/streaming.py in read_line(self, sep)
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     506                 cache_content = False
# --> 507                 data = self._fp.read(amt) if not fp_closed else b""
#     508                 if (
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/http/client.py in read(self, amt)
#     456             b = bytearray(amt)
# --> 457             n = self.readinto(b)
#     458             return memoryview(b)[:n].tobytes()
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/http/client.py in readinto(self, b)
#     490         if self.chunked:
# --> 491             return self._readinto_chunked(b)
#     492
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/http/client.py in _readinto_chunked(self, b)
#     585             while True:
# --> 586                 chunk_left = self._get_chunk_left()
#     587                 if chunk_left is None:
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/http/client.py in _get_chunk_left(self)
#     553             try:
# --> 554                 chunk_left = self._read_next_chunk_size()
#     555             except ValueError:
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/http/client.py in _read_next_chunk_size(self)
#     513         # Read the next chunk size from the file
# --> 514         line = self.fp.readline(_MAXLINE + 1)
#     515         if len(line) > _MAXLINE:
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/socket.py in readinto(self, b)
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     324         except OpenSSL.SSL.WantReadError:
# --> 325             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     326                 raise timeout("The read operation timed out")
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/urllib3/util/wait.py in wait_for_read(sock, timeout)
#     145     """
# --> 146     return wait_for_socket(sock, read=True, timeout=timeout)
#     147
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/urllib3/util/wait.py in poll_wait_for_socket(sock, read, write, timeout)
#     106
# --> 107     return bool(_retry_on_intr(do_poll, timeout))
#     108
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/urllib3/util/wait.py in _retry_on_intr(fn, timeout)
#      42     def _retry_on_intr(fn, timeout):
# ---> 43         return fn(timeout)
#      44
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/urllib3/util/wait.py in do_poll(t)
#     104             t *= 1000
# --> 105         return poll_obj.poll(t)
#     106
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# WantReadError                             Traceback (most recent call last)
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     312         try:
# --> 313             return self.connection.recv_into(*args, **kwargs)
#     314         except OpenSSL.SSL.SysCallError as e:
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1839             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1840         self._raise_ssl_error(self._ssl, result)
#    1841
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1645         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1646             raise WantReadError()
#    1647         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-ecc96d25230b> in <module>
#      19         myStreamListener = MyStreamListener()
#      20         myStream = tweepy.Stream(auth = api.auth, listener = myStreamListener)
# ---> 21         myStream.filter(languages=["en"], locations=GEOBOX_NAIROBI)
#      22         dbconn.commit()
#      23
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/tweepy/streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/tweepy/streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/tweepy/streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/tweepy/streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     505             else:
#     506                 cache_content = False
# --> 507                 data = self._fp.read(amt) if not fp_closed else b""
#     508                 if (
#     509                     amt != 0 and not data
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/http/client.py in read(self, amt)
#     455             # Amount is given, implement using readinto
#     456             b = bytearray(amt)
# --> 457             n = self.readinto(b)
#     458             return memoryview(b)[:n].tobytes()
#     459         else:
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/http/client.py in readinto(self, b)
#     489
#     490         if self.chunked:
# --> 491             return self._readinto_chunked(b)
#     492
#     493         if self.length is not None:
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/http/client.py in _readinto_chunked(self, b)
#     584         try:
#     585             while True:
# --> 586                 chunk_left = self._get_chunk_left()
#     587                 if chunk_left is None:
#     588                     return total_bytes
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/http/client.py in _get_chunk_left(self)
#     552                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     553             try:
# --> 554                 chunk_left = self._read_next_chunk_size()
#     555             except ValueError:
#     556                 raise IncompleteRead(b'')
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/http/client.py in _read_next_chunk_size(self)
#     512     def _read_next_chunk_size(self):
#     513         # Read the next chunk size from the file
# --> 514         line = self.fp.readline(_MAXLINE + 1)
#     515         if len(line) > _MAXLINE:
#     516             raise LineTooLong("chunk size")
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     323                 raise
#     324         except OpenSSL.SSL.WantReadError:
# --> 325             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     326                 raise timeout("The read operation timed out")
#     327             else:
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/urllib3/util/wait.py in wait_for_read(sock, timeout)
#     144     Returns True if the socket is readable, or False if the timeout expired.
#     145     """
# --> 146     return wait_for_socket(sock, read=True, timeout=timeout)
#     147
#     148
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/urllib3/util/wait.py in poll_wait_for_socket(sock, read, write, timeout)
#     105         return poll_obj.poll(t)
#     106
# --> 107     return bool(_retry_on_intr(do_poll, timeout))
#     108
#     109
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/urllib3/util/wait.py in _retry_on_intr(fn, timeout)
#      41     # Modern Python, that retries syscalls by default
#      42     def _retry_on_intr(fn, timeout):
# ---> 43         return fn(timeout)
#      44
#      45
#
# ~/anaconda3/envs/nairobi_alive/lib/python3.7/site-packages/urllib3/util/wait.py in do_poll(t)
#     103         if t is not None:
#     104             t *= 1000
# --> 105         return poll_obj.poll(t)
#     106
#     107     return bool(_retry_on_intr(do_poll, timeout))
#
# KeyboardInterrupt:

# %%
# !pip freeze > requirements.txt

# %%
#Fetch data from database

# %%
import psycopg2 as pg
import pandas.io.sql as psql
import time
import pandas as pd
def getdata():
    connection = pg.connect("host=ec2-52-207-25-133.compute-1.amazonaws.com dbname=d8e9au4m77k9b1 user=twvlbubsgabvpj password=53cf31e1928ac9f0ec3ec5554a92bfa96ddb693b7bb3b31df2bbf3784cc66f6a")
    dataframe = psql.read_sql('SELECT * FROM nairobitweets', connection)
    dataframe.count
    print(dataframe)
    time.sleep(60)

while True:
    getdata()
